# %%
# String with escape sequence charator (\t = tab like space and \n = new line)
str1 = "This is a string.\tWe are creating it in Python."
print (str1)
# Out:
# This is a string.	We are creating it in Python.

# %%
# Concatenstion means adding two strings
str1 = "Sangeet"
str2 = "Das"
print (str1+str2)
# Out:
# SangeetDas

# %%
# lenght find out with len function
str1 = "Sangeet"
len1 = len(str1)
print (len1)

str2 = "Das"
len2 = len(str2)
print(len2)

final_str = str1 + " " +str2
print (final_str)
print (len(final_str))
# Out:
# 7
# 3
# Sangeet Das
# 11

# %%
# Indexing
str = "Sangeet Das"
ch = str[0]
print(ch)
# Out:
# S

# %%
str = "Sangeet Das"
print(str[3])
# Out:
# g

# %%
# Slicing means return slicng part what I meantions in square bracket
str = "Chapainawabganj"
print(str[2:5])
# Out:
# apa

# %%
# Slicing negative index (count from last and statr with -1)
str = "Mango"
print (str[-3:-1])
# Out:
# ng

# %%
# String Function (endswith), if its end with double cottation value then its says true or false
str = "I live in London"
print (str.endswith("don"))
# Out:
# True

# %%
# String Function (capitalize), its make first charactor in Capital letter
str = "i live in london"
print(str.capitalize())
# Out:
# I live in london

# %%
# String Function (Replace), its replace old value from data
str = "I eat apple"
print (str.replace("a","G"))
# Out:
# I eGt Gpple

# %%
# String Function (find),its find word andwhen it get the word its send the index for words
str = "I eat apple"
print (str.find("a"))
# Out:
# 3

# %%
# String Function (Count), its count letter/word/words or same word how many in paragraph
str = "I eat apple and I eat mango"
print (str.count("eat"))
# Out:
# 2

# %%
# Task WAP to input user name and & print its lenght
name = input("input your name:  ")
print ("lenght of your name is", len(" name "))
# Out:
# input your name:   sangeet
# lenght of your name is 6

# %%
# Task WAP to find the occurance of '$' in the strings
str = "I $am I earn in $ I will invest in$"
print (str.count('$'))
# Out:
# 3

# %%
# Conditional Statements = if-elif-else (if age is greater than equal 20 then he can apply for driving and give vote)
age = 32
if (age>= 20):
    print("Can vote and apply for drive license ")
# Out:
# Can vote and apply for drive license

# %%
# if elif statement 
light = "red"
if (light == "red"):
    print ("Stop") 
elif (light == "green"):
    print ("Go")
elif (light == "yellow"):
    print ("Wait")
# Out:
# Stop

# %%
# if else
age = 19
if (age>= 18):
    print ("Can Vote")
else:
    print ("Can not vote")
# Out:
# Can Vote

# %%
# if-elif-else (not matching any clour so else will be print)
light = "Pink"
if (light == "red"):
    print ("Stop")
elif (light == "green"):
    print ("Go")
elif (light == "yellow"):
    print ("Wait")
else :
    print ("Light is not working")
# Out:
# Light is not working

# %%
# WAP time 42 mins without input
marks = 72
if (marks >= 90):
    print ("Grade A")
elif (marks >= 80):
    print ("Grade B")
elif (marks >=70 ):
    print ("Grade c")
else :
    print ("Fail")
# Out:
# Grade c

# %%
# WAP time 42 mins without input
marks = int (input ("Input your number : "))
if (marks >= 90):
    print ("Grade A")
elif (marks >= 80):
    print ("Grade B")
elif (marks >= 70):
    print ("Grade C")
else:
    print ("Fail")
# Out:
# Input your number :  71
# Grade C

# %%
# Nesting  (carefull about if- else spacing)
age = 80
if (age >= 18):
    if (age >= 80):
        print ("Can Not Drive")
    else :
        print ("Can Drive")
else :
    print ("Can not drive")
# Out:
# Can Not Drive

# %%
# WAP to check if a number entered by user is odd or even (1,3,5= odd and 2,4,6= even)
num = 13
rem = num % 2
if (rem == 0):
    print ("Even")
else :
    print ("Odd")
# Out:
# Odd

# %%
# WAP to check if a number entered by user is odd or even (1,3,5= odd and 2,4,6= even)
num = 14
if (num % 2 == 0):
    print ("Even")
else:
    print ("Odd")
# Out:
# Even

# %%
# WAP fint the greatest of 3 numbers by user 
a = int (input ("Enter first number: "))
b = int (input ("Enter second number: "))
c = int (input ("Enter third number: "))

if (a>=b and a>=c ):
    print ("First number is largest", a)
elif (b>=c):
    print ("Second number is largest")
else:
    print ("Third number is largest")
# Out:
# Enter first number:  22
# Enter second number:  23
# Enter third number:  24
# Third number is largest

# %%
# WAP to check if a number is multiple of 7 or not
a = int (input("Enter number: "))
if (a % 2 == 0):
    print ("Multiple of 7")
else :
    print ("Not Multiple of 7")
# Out:
# Enter number:  6
# Multiple of 7
